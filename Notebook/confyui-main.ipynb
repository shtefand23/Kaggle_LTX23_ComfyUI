# %% [markdown]
# <h1 style="color:#2bb2c0; text-align:center;">🎉 Добро пожаловать! Устанавливает ComfyUI 🎉</h1>
# <h2 style="color:#2bb2c0; text-align:center;">Этот блокнот специально создан для группы <a href="https://vk.com/theangel_lab">THE ANGEL AI | AI БЕЗ БОЛИ</a></h2>
#
# <div style="border-left: 8px solid #ab274f; padding-left: 15px; margin: 20px 0; background-color: #000000; padding: 15px;">
# <strong style="color:#2bb2c0;">О чём наша группа:</strong><br>
# • Гайды по LTX 2.3, Wan 2.2, Flux2, AI Agent и другим нейросетям<br>
# • Бесплатные GPU-платформы (Kaggle, Colab, Lightning AI)<br>
# • Автоматизация через ComfyUI<br>
# • Промты, которые реально работают<br>
# Всё на русском языке, без лишней информации. Присоединяйтесь к нашей группе, чтобы первыми узнавать актуальные новости о блокноте!
# </div>
#
# <div style="text-align: center; margin: 25px 0;">
# <a href="https://vk.com/theangel_lab" target="_blank" style="display: inline-block; padding: 14px 32px; margin: 10px; background-color: #106ee0; color: #000000; text-decoration: none; border-radius: 50px; font-weight: bold; font-size: 16px; border: 6px solid #6f2540; transition: all 0.3s ease;">
# 🐰 Наша группа ВКонтакте
# </a>
#
# <a href="https://boosty.to/the_angel" target="_blank" style="display: inline-block; padding: 14px 32px; margin: 10px; background-color: #00940b; color: #000000; text-decoration: none; border-radius: 50px; font-weight: bold; font-size: 16px; border: 6px solid #6f2540; transition: all 0.3s ease;">
# 💝 Поддержать проект
# </a>
# </div>

# %%
import sys
from IPython.display import clear_output, display, HTML
def print_status(message):
    display(HTML(f"<h2 style='color: green;'>✅ {message}</h2>"))
# %cd /kaggle/working/
# !git clone https://github.com/THE-ANGEL-AI/Kaggle_Workspace.git
print_status("Проверю обнову в THE ANGEL AI | AI БЕЗ БОЛИ")
clear_output()
print_status("Проверю Все ли на месте потом запущу...")
# %cd /kaggle/working/Kaggle_Workspace/instal
clear_output()
# %run start.py
