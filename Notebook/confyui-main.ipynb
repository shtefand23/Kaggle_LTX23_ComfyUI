# %% [markdown]
# <h1 style="color:#2bb2c0; text-align:center;">🎉 Welcome! Installing ComfyUI 🎉</h1>
# <h2 style="color:#2bb2c0; text-align:center;">This notebook was specially created for the group <a href="https://vk.com/theangel_lab">THE ANGEL AI | AI WITHOUT PAIN</a></h2>
#
# <div style="border-left: 8px solid #ab274f; padding-left: 15px; margin: 20px 0; background-color: #000000; padding: 15px;">
# <strong style="color:#2bb2c0;">What our group is about:</strong><br>
# • Guides for LTX 2.3, Wan 2.2, Flux2, AI Agent and other neural networks<br>
# • Free GPU platforms (Kaggle, Colab, Lightning AI)<br>
# • Automation via ComfyUI<br>
# • Prompts that actually work<br>
# Everything in Russian, no unnecessary info. Join our group to be the first to learn about notebook updates!
# </div>
#
# <div style="text-align: center; margin: 25px 0;">
# <a href="https://vk.com/theangel_lab" target="_blank" style="display: inline-block; padding: 14px 32px; margin: 10px; background-color: #106ee0; color: #000000; text-decoration: none; border-radius: 50px; font-weight: bold; font-size: 16px; border: 6px solid #6f2540; transition: all 0.3s ease;">
# 🐰 Our VK Group
# </a>
#
# <a href="https://boosty.to/the_angel" target="_blank" style="display: inline-block; padding: 14px 32px; margin: 10px; background-color: #00940b; color: #000000; text-decoration: none; border-radius: 50px; font-weight: bold; font-size: 16px; border: 6px solid #6f2540; transition: all 0.3s ease;">
# 💝 Support the Project
# </a>
# </div>

# %%
# !cd /kaggle/working/Kagle && git pull
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 13 (delta 10), reused 10 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (13/13), 5.56 KiB | 711.00 KiB/s, done.
# From https://github.com/THE-ANGEL-AI/Kaggle_Workspace
#    f616473..80dc8ec  main       -> origin/main
# Updating f616473..80dc8ec
# Fast-forward
#  instal/launcher.py   | 266 +++++++++++++++++++++++++++++++++------------------
#  instal/logging_ui.py |  57 ++++++++++-
#  2 files changed, 231 insertions(+), 92 deletions(-)

# %%
import sys
from IPython.display import clear_output, display, HTML
def print_status(message):
    display(HTML(f"<h2 style='color: green;'>✅ {message}</h2>"))
# %cd /kaggle/working/
# !git clone https://github.com/shtefand23/Kagle.git
print_status("Checking for updates in THE ANGEL AI | AI WITHOUT PAIN")
clear_output()
print_status("Checking everything is in place then launching...")
# %cd /kaggle/working/Kagle/instal
#clear_output()
# %run start.py
# Out:
# <h2 style='color: green;'>✅ Checking everything is in place then launching...</h2>
# /kaggle/working/Kaggle_Workspace/instal
# ...
# 🔒 [PROTECTION] Kaggle protection system activated!
# 🔒 [PROTECTION] Will send pulse every 5 minutes
#
# 💓 [11:39:04] ComfyUI active, waiting for request...
# 💓 [11:39:21] ComfyUI active, waiting for request...
# 💓 [11:40:29] ComfyUI active, waiting for request...
# 💓 [11:41:50] ComfyUI active, waiting for request...
# 💓 [11:41:59] ComfyUI active, waiting for request...
# 💓 [11:42:40] ComfyUI active, waiting for request...
# 💓 [11:43:57] ComfyUI active, waiting for request...
# 💓 [11:44:04] ComfyUI active, waiting for request...
# 💓 [11:44:21] ComfyUI active, waiting for request...
# 💓 [11:45:29] ComfyUI active, waiting for request...
# 💓 [11:46:50] ComfyUI active, waiting for request...
# 💓 [11:46:59] ComfyUI active, waiting for request...
# 💓 [11:47:40] ComfyUI active, waiting for request...
# 💓 [11:48:57] ComfyUI active, waiting for request...
# ...
