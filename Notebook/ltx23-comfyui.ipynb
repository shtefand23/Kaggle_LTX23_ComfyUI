# %% [markdown]
# # 🎬 LTX 2.3 Director V2 Beta — Video Generation on Kaggle (2×T4)
#
# This notebook installs ComfyUI with LTX 2.3 Director V2 Beta.
#
# **Workflows included:**
# - `LTX_Director-V2-Beta.json` — LTX Director V2 Beta (full featured)
# - `LTX23Legacy.json` — Standard LTX 2.3 video generation
# - `LTX23LTXDirector13.json` — LTX Director v1.3 (guided video)
# - `LTX23LTXDirector2.json` — LTX Director v2 (advanced guided video)
#
# **Requirements:** Add this dataset to your session:
# - [LTX Director Models](https://www.kaggle.com/datasets/martasteiner/ltxdirector) (all 19 models — diffusion, encoders, VAE, LoRAs)

# %%
import sys
from IPython.display import clear_output, display, HTML

def print_status(message):
    display(HTML(f"<h2 style='color: green;'>✅ {message}</h2>"))

# %cd /kaggle/working/
# !git clone https://github.com/shtefand23/Kaggle_LTX23_ComfyUI.git
clear_output()
# %cd /kaggle/working/Kaggle_LTX23_ComfyUI/instal
print_status("Auto-update built-in...")
# %run start.py
